# %% [markdown]
# <a href="https://colab.research.google.com/github/mdnafees33/Service-care-solutions/blob/main/intership_first_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/archive (14).zip')
df.head(4)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished

# %%
df.drop_duplicates()
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of House Pricing Dataset")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3722198625.py in <cell line: 0>()
#       1 plt.figure(figsize=(10, 8))
# ----> 2 sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
#       3 plt.title("Correlation Heatmap of House Pricing Dataset")
#       4 plt.show()
#
# NameError: name 'corr_matrix' is not defined

# %%
corr_matrix = df.corr(numeric_only=True)

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap of House Pricing Dataset")
plt.show()

# %%
df.drop(columns=['furnishingstatus'],inplace=True)

# %%
df.head(4)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea
# 0              no             yes        2      yes
# 1              no             yes        3       no
# 2              no              no        2      yes
# 3              no             yes        3      yes

# %%
df.isnull().sum()
# Out:
# price              0
# area               0
# bedrooms           0
# bathrooms          0
# stories            0
# mainroad           0
# guestroom          0
# basement           0
# hotwaterheating    0
# airconditioning    0
# parking            0
# prefarea           0
# dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.boxplot(df)
plt.show()

# %%
q1=df['price'].quantile(0.25)
q3=df['price'].quantile(0.75)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)
outlier=df[(df['price']<lower_limit) | (df['price']>upper_limit)]
outlier_per=len(outlier)/len(df)*100
print(outlier_per)
df = df[(df['price'] >= lower_limit) & (df['price'] <= upper_limit)]
q1=df['price'].quantile(0.25)
q3=df['price'].quantile(0.75)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)
outlier=df[(df['price']<lower_limit) | (df['price']>upper_limit)]
outlier_per=len(outlier)/len(df)*100
print(outlier_per)
# Out:
# 2.7522935779816518
# 0.7547169811320755

# %%
# Histogram for price
plt.figure(figsize=(10,5))
sns.histplot(df['price'], bins=50, kde=True)
plt.title("Price Distribution")
plt.show()

# %%
import numpy as np
y = np.log1p(df['price'])

# %%
q1=df['area'].quantile(0.25)
q3=df['area'].quantile(0.75)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)
outlier=df[(df['area']<lower_limit) | (df['area']>upper_limit)]
outlier_per=len(outlier)/len(df)*100
print(outlier_per)
df = df[(df['area'] >= lower_limit) & (df['area'] <= upper_limit)]
q1=df['area'].quantile(0.25)
q3=df['area'].quantile(0.75)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)
outlier=df[(df['area']<lower_limit) | (df['area']>upper_limit)]
outlier_per=len(outlier)/len(df)*100
print(outlier_per)
# Out:
# 2.4528301886792456
# 0.7736943907156674

# %%
df['area']=df['area'].clip(lower=lower_limit,upper=upper_limit)

# %%
# Histogram for area
plt.figure(figsize=(10,5))
sns.histplot(df['area'], bins=50, kde=True)
plt.title("Area Distribution")
plt.show()

# %%
import numpy as np
y = np.log1p(df['area'])

# %%
q1=df['bedrooms'].quantile(0.25)
q3=df['bedrooms'].quantile(0.75)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)
outlier=df[(df['bedrooms']<lower_limit) | (df['bedrooms']>upper_limit)]
outlier_per=len(outlier)/len(df)*100
print(outlier_per)
df = df[(df['bedrooms'] >= lower_limit) & (df['bedrooms'] <= upper_limit)]
q1=df['bedrooms'].quantile(0.25)
q3=df['bedrooms'].quantile(0.75)
iqr=q3-q1
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)
outlier=df[(df['bedrooms']<lower_limit) | (df['bedrooms']>upper_limit)]
outlier_per=len(outlier)/len(df)*100
print(outlier_per)
# Out:
# 2.127659574468085
# 0.0

# %%
df['stories'].unique()
# Out:
# array([2, 4, 1, 3])

# %%
df['parking'].unique()
# Out:
# array([2, 1, 0, 3])

# %%
df['mainroad'].unique()
# Out:
# array([1, 0])

# %%
df['bathrooms'].unique()
# Out:
# array([1, 2, 3])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['mainroad']=le.fit_transform(df['mainroad'])
df['guestroom']=le.fit_transform(df['guestroom'])
df['basement']=le.fit_transform(df['basement'])
df['hotwaterheating']=le.fit_transform(df['hotwaterheating'])
df['airconditioning']=le.fit_transform(df['airconditioning'])
df['prefarea']=le.fit_transform(df['prefarea'])

# %%
df.head(4)
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 15  9100000  6000         4          1        2         1          0
# 16  9100000  6600         4          2        2         1          1
# 17  8960000  8500         3          2        4         1          0
# 18  8890000  4600         3          2        2         1          1
#
#     basement  hotwaterheating  airconditioning  parking  prefarea
# 15         1                0                0        2         0
# 16         1                0                1        1         1
# 17         0                0                1        2         0
# 18         0                0                1        2         0

# %%
x= df.iloc[:, 1:]
y=df['price']

# %%
x.head(4)
# Out:
#     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 15  6000         4          1        2         1          0         1
# 16  6600         4          2        2         1          1         1
# 17  8500         3          2        4         1          0         0
# 18  4600         3          2        2         1          1         0
#
#     hotwaterheating  airconditioning  parking  prefarea
# 15                0                0        2         0
# 16                0                1        1         1
# 17                0                1        2         0
# 18                0                1        2         0

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.drop('price',axis=1),df['price'],test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 69.05527950968894

# %%
from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.1)  # alpha controls regularization strength
lasso.fit(x_train, y_train)

lr.score(x_test,y_test)*100
# Out:
# 69.05527950968894

# %%
from sklearn.linear_model import Ridge
ridge = Ridge(alpha=1.0)  # alpha controls regularization strength
ridge.fit(x_train, y_train)
# Out:
# Ridge()

# %%
lr.score(x_test,y_test)*100
# Out:
# 69.05527950968894
